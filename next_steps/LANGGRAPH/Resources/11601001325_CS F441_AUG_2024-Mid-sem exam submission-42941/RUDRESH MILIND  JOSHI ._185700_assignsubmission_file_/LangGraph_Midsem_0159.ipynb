# %%
! pip install -U langchain_community langchain-openai langchain-anthropic langchain langgraph bs4
# Out:
# Requirement already satisfied: langchain_community in ./venv_mid_sem_exam/lib/python3.12/site-packages (0.3.2)
# Requirement already satisfied: langchain-openai in ./venv_mid_sem_exam/lib/python3.12/site-packages (0.2.2)
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain in ./venv_mid_sem_exam/lib/python3.12/site-packages (0.3.3)
# Requirement already satisfied: langgraph in ./venv_mid_sem_exam/lib/python3.12/site-packages (0.2.34)
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: PyYAML>=5.3 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (3.10.9)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.10 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (0.3.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (0.1.132)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-openai) (1.51.2)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-openai) (0.8.0)
# Collecting anthropic<1,>=0.30.0 (from langchain-anthropic)
#   Downloading anthropic-0.36.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-anthropic) (0.7.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-anthropic) (2.9.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain) (0.3.0)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.0.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langgraph) (2.0.1)
# Requirement already satisfied: beautifulsoup4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.6.1)
# Requirement already satisfied: sniffio in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: tokenizers>=0.13.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (0.20.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from anthropic<1,>=0.30.0->langchain-anthropic) (4.12.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.10->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.10->langchain_community) (24.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langgraph-checkpoint<3.0.0,>=2.0.0->langgraph) (1.1.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: tqdm>4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.1.1)
# Requirement already satisfied: regex>=2022.1.18 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.9.11)
# Requirement already satisfied: soupsieve>1.2 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: httpcore==1.* in ./venv_mid_sem_exam/lib/python3.12/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain-anthropic) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.30.0->langchain-anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.10->langchain_community) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (0.25.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (0.2.0)
# Requirement already satisfied: filelock in ./venv_mid_sem_exam/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv_mid_sem_exam/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.30.0->langchain-anthropic) (2024.9.0)
# Downloading langchain_anthropic-0.2.3-py3-none-any.whl (21 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading anthropic-0.36.0-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 kB 4.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: bs4, anthropic, langchain-anthropic
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/home/fduser/Desktop/Langgraph/venv_mid_sem_exam/lib/python3.12/site-packages/README.rst'
# Check the permissions.

# %%
import getpass
import os


def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")


_set_env("OPENAI_API_KEY")
# Out:
# OPENAI_API_KEY:  ········

# %%
from langchain import hub
from langchain.chat_models import ChatOpenAI
from langchain.tools import FileTool
from langchain.graph import StateGraph
from pydantic import BaseModel, Field
from typing import List

# Define the State model using Pydantic
class State(BaseModel):
    java_code: str = Field(default="")
    rubric: str = Field(default="")
    class_names: List[str] = Field(default_factory=list)
    evaluation_response: str = Field(default="")
    marks_list: str = Field(default="")
    total_marks: int = Field(default=0)
    final_evaluation: str = Field(default="")

# Initialize the LLM
llm = ChatOpenAI(model="gpt-4-turbo-preview")

# Define the nodes for the StateGraph workflow
def read_java_file(state: State, java_file_path: str):
    """Reads Java code from the specified file and updates the state."""
    with open(java_file_path, 'r') as java_file:
        state.java_code = java_file.read()

def read_rubric_file(state: State, rubric_file_path: str):
    """Reads the rubric from the specified file and updates the state."""
    with open(rubric_file_path, 'r') as rubric_file:
        state.rubric = rubric_file.read()

def extract_class_names(state: State):
    """Extracts all class names used in the Java code and updates the state."""
    class_extraction_prompt = f"""
    I have the following Java code:
    ```
    {state.java_code}
    ```
    Please extract all class names used in the code.
    """
    class_response = llm(class_extraction_prompt)
    state.class_names = class_response.strip().split(',')

def evaluate_classes(state: State):
    """Evaluates each Java class based on the rubric and updates the state."""
    evaluation_prompt = f"""
    I have the following rubric/marking scheme:
    ```
    {state.rubric}
    ```
    I also have the following list of Java classes: {', '.join(state.class_names)}.
    Please evaluate each class based on the most relevant part of the rubric.
    Provide specific feedback for each class.
    """
    state.evaluation_response = llm(evaluation_prompt)

def re_evaluate(state: State):
    """Re-evaluates the previously obtained evaluation and updates the state."""
    re_evaluation_prompt = f"""
    Based on the previous evaluation, please provide a re-evaluation of the classes.
    Here is the initial evaluation:
    ```
    {state.evaluation_response}
    ```
    Provide detailed comments and additional insights if necessary.
    """
    state.evaluation_response = llm(re_evaluation_prompt)

def extract_marks(state: State, student_code_path: str):
    """Extracts marks from the evaluation response based on the student's Java code."""
    with open(student_code_path, 'r') as student_file:
        student_code = student_file.read()

    marks_extraction_prompt = f"""
    I have the following student's Java code:
    ```
    {student_code}
    ```

    And the following evaluation points for the student's performance:
    ```
    {state.evaluation_response}
    ```

    Please extract the marks awarded for each criterion in the evaluation as a comma-separated list of marks.
    """
    marks_response = llm(marks_extraction_prompt)
    state.marks_list = marks_response.strip()

def sum_marks(state: State):
    """Sums the extracted marks and updates the total marks in the state."""
    marks = [int(mark.strip()) for mark in state.marks_list.split(',') if mark.strip().isdigit()]
    state.total_marks = sum(marks)

def generate_final_evaluation(state: State):
    """Generates the final evaluation summary and updates the state."""
    final_evaluation_prompt = f"""
    I have extracted the following marks for the student: {state.marks_list}.

    Based on these marks, the total score is: {state.total_marks}.

    Now, please provide detailed feedback and a final assessment for the student's performance in their Java classes.
    """
    state.final_evaluation = llm(final_evaluation_prompt)

def save_final_evaluation(state: State):
    """Saves the final evaluation and total marks to a file."""
    with open('final_evaluation.txt', 'w') as eval_file:
        eval_file.write("Final Evaluation:\n")
        eval_file.write(state.final_evaluation)
        eval_file.write(f"\nTotal Marks Obtained: {state.total_marks}\n")

# Create a StateGraph to manage the workflow
graph = StateGraph()

# Instantiate the state model
state = State()

# Define the nodes in the graph workflow
graph.add_node('Read Java File', read_java_file, state, "/path/to/student_code.java")
graph.add_node('Read Rubric File', read_rubric_file, state, "/path/to/rubric_file.txt")
graph.add_node('Extract Class Names', extract_class_names, state)
graph.add_node('Evaluate Classes', evaluate_classes, state)
graph.add_node('Re-Evaluate Classes', re_evaluate, state)
graph.add_node('Extract Marks', extract_marks, state, "/path/to/student_code.java")
graph.add_node('Sum Marks', sum_marks, state)
graph.add_node('Generate Final Evaluation', generate_final_evaluation, state)
graph.add_node('Save Final Evaluation', save_final_evaluation, state)

# Connect the nodes to create the workflow
graph.connect('Read Java File', 'Read Rubric File')
graph.connect('Read Rubric File', 'Extract Class Names')
graph.connect('Extract Class Names', 'Evaluate Classes')
graph.connect('Evaluate Classes', 'Re-Evaluate Classes')
graph.connect('Re-Evaluate Classes', 'Extract Marks')
graph.connect('Extract Marks', 'Sum Marks')
graph.connect('Sum Marks', 'Generate Final Evaluation')
graph.connect('Generate Final Evaluation', 'Save Final Evaluation')

# Run the workflow
graph.run()
print("Final evaluation saved in 'final_evaluation.txt'.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 from langchain import hub
#       2 from langchain.chat_models import ChatOpenAI
# ----> 3 from langchain.tools import FileTool
#       4 from langchain.graph import StateGraph
#       5 from pydantic import BaseModel, Field
#
# ImportError: cannot import name 'FileTool' from 'langchain.tools' (/home/fduser/Desktop/Langgraph/venv_mid_sem_exam/lib/python3.12/site-packages/langchain/tools/__init__.py)
